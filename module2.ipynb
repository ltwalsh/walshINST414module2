# %%
import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

# %%
player_df = pd.read_csv('module2playerdata.csv', low_memory=False)

# %%
player_df
# Out:
#        player_id  version                   name                   full_name  \
# 0         239085  3/20/24         Erling Haaland        Erling Braut Haaland
# 1         231747  3/20/24          Kylian Mbappé        Kylian Mbappé Lottin
# 2         192985  3/20/24        Kevin De Bruyne             Kevin De Bruyne
# 3         231866  3/20/24                  Rodri  Rodrigo Hernández Cascante
# 4         202126  3/20/24             Harry Kane                  Harry Kane
# ...          ...      ...                    ...                         ...
# 18326     272761  3/20/24           Lyu Jiaqiang             吕佳强 Lü Jiaqiang
# 18327     275601  3/20/24          Callum Warren               Callum Warren
# 18328      71064  3/20/24       Ishaan Shishodia            Ishaan Shishodia
# 18329     269541  3/20/24              Wu Yuhang               吴宇航 Wu Yuhang
# 18330     277493  3/20/24  Fredy Chawngthansanga       Fredy Chawngthansanga
#
#                                              description  \
# 0      Erling Haaland (Erling Braut Haaland, born 21 ...
# 1      Kylian Mbappé (Kylian Mbappé Lottin, born 20 D...
# 2      Kevin De Bruyne (born 28 June 1991) is a Belgi...
# 3      Rodri (born 22 June 1996) is a Spanish footbal...
# 4      Harry Kane (born 28 July 1993) is a British fo...
# ...                                                  ...
# 18326  Lyu Jiaqiang (吕佳强, Lü Jiaqiang, born 11 April ...
# 18327  Callum Warren (born 16 March 2005) is an Irish...
# 18328  Ishaan Shishodia (born 31 August 2005) is an I...
# 18329  Wu Yuhang (吴宇航, Wu Yuhang, born 16 February 20...
# 18330  Fredy Chawngthansanga (born 25 May 2003) is an...
#
#                                                    image  height_cm  \
# 0      https://cdn.sofifa.net/players/239/085/24_120.png        195
# 1      https://cdn.sofifa.net/players/231/747/24_120.png        182
# 2      https://cdn.sofifa.net/players/192/985/24_120.png        181
# 3      https://cdn.sofifa.net/players/231/866/24_120.png        191
# 4      https://cdn.sofifa.net/players/202/126/24_120.png        188
# ...                                                  ...        ...
# 18326  https://cdn.sofifa.net/players/272/761/24_120.png        180
# 18327  https://cdn.sofifa.net/players/275/601/24_120.png        172
# 18328  https://cdn.sofifa.net/players/071/064/24_120.png        177
# 18329  https://cdn.sofifa.net/players/269/541/24_120.png        182
# 18330  https://cdn.sofifa.net/players/277/493/24_120.png        165
#
#        weight_kg       dob positions  ...  composure  defensive_awareness  \
# 0             94   7/21/00        ST  ...         87                   38
# 1             75  12/20/98     ST,LW  ...         88                   26
# 2             75   6/28/91    CM,CAM  ...         88                   66
# 3             82   6/22/96    CDM,CM  ...         87                   92
# 4             85   7/28/93        ST  ...         92                   46
# ...          ...       ...       ...  ...        ...                  ...
# 18326         65   4/11/05        CB  ...         37                   51
# 18327         67   3/16/05       CAM  ...         51                   29
# 18328         70   8/31/05    CM,CAM  ...         44                   33
# 18329         75   2/16/01       CDM  ...         39                   40
# 18330         64   5/25/03       CAM  ...         46                   31
#
#       standing_tackle sliding_tackle gk_diving gk_handling gk_kicking  \
# 0                  47             29         7          14         13
# 1                  34             32        13           5          7
# 2                  70             53        15          13          5
# 3                  87             78        10          10          7
# 4                  46             38         8          10         11
# ...               ...            ...       ...         ...        ...
# 18326              50             53        15          12          8
# 18327              38             34         7          14         13
# 18328              38             42        12          11         13
# 18329              45             51        11          12          5
# 18330              32             29        12          10         11
#
#        gk_positioning gk_reflexes  \
# 0                  11         7.0
# 1                  11         6.0
# 2                  10        13.0
# 3                  14         8.0
# 4                  14        11.0
# ...               ...         ...
# 18326               7        15.0
# 18327               7        10.0
# 18328              13        13.0
# 18329              13         8.0
# 18330               6         8.0
#
#                                              play_styles
# 0                    Acrobatic +,Power Header,Quick Step
# 1      Quick Step +,Finesse Shot,Rapid,Flair,Trivela,...
# 2      Incisive Pass +,Dead Ball,Pinged Pass,Long Bal...
# 3             Power Shot +,Long Ball Pass,Bruiser,Aerial
# 4      Incisive Pass +,Long Ball Pass,First Touch,Tri...
# ...                                                  ...
# 18326                                                NaN
# 18327                                                NaN
# 18328                                                NaN
# 18329                                                NaN
# 18330                                                NaN
#
# [18331 rows x 76 columns]

# %%
final_df = player_df[['name', 'club_name', 'club_league_name', 'positions']]

# %%
my_list = ['Premier League', 'Ligue 1', 'La Liga', 'Serie A', 'Bundesliga']
results = final_df.loc[final_df["club_league_name"].isin(my_list)]

# %%
results
# Out:
#                       name            club_name club_league_name positions
# 0           Erling Haaland      Manchester City   Premier League        ST
# 1            Kylian Mbappé  Paris Saint Germain          Ligue 1     ST,LW
# 2          Kevin De Bruyne      Manchester City   Premier League    CM,CAM
# 3                    Rodri      Manchester City   Premier League    CDM,CM
# 4               Harry Kane    FC Bayern München       Bundesliga        ST
# ...                    ...                  ...              ...       ...
# 18040  Michael Morgenstern       Wolfsberger AC       Bundesliga        ST
# 18075      Kevin Radulovic       Blau-Weiß Linz       Bundesliga        GK
# 18099      Bego Kujrakovic   Austria Klagenfurt       Bundesliga       CDM
# 18163          Sam Proctor          Aston Villa   Premier League        GK
# 18218  Filippo Lapo Vertua               Empoli          Serie A        GK
#
# [3223 rows x 4 columns]

# %%
G = nx.Graph()

#add the nodes and edges
for index, row in results.iterrows():
    player = row['name']
    club = row['club_name']
    league = row['club_league_name']
    positions = row['positions']
    
    #add the players
    G.add_node(player, type='player')
    
    #add the clubs
    G.add_node(club, type='club', league=league)
    
    #add edges between players and clubs
    G.add_edge(player, club)
    
    #add edges between player and positions
    G.add_edge(player, positions)


nx.write_gexf(G, "soccer_network.gexf")

# %%
G = nx.DiGraph()

#add nodes and edges
for index, row in results.iterrows():
    player = row['name']
    position = row['positions']
    club = row['club_name']
    league = row['club_league_name']
    
    #add nodes for players and positions
    G.add_node(player, type='player')
    G.add_node(position, type='position')
    
    #add edges between player and position
    G.add_edge(player, position)

#get the degree centrality
degree_centrality = nx.degree_centrality(G)

#get the positions with the highest degree centrality
highest_centrality_positions = sorted(degree_centrality, key=degree_centrality.get, reverse=True)[:5]

#print the centrality values
print("Positions with highest degree centrality:")
for position in highest_centrality_positions:
    centrality_value = degree_centrality[position]
    print(f"{position}: {centrality_value}")
# Out:
# Positions with highest degree centrality:
# CB: 0.12686357243319268
# GK: 0.10576652601969058
# ST: 0.08045007032348804
# CDM,CM: 0.048663853727144865
# CM,CDM: 0.04050632911392405
